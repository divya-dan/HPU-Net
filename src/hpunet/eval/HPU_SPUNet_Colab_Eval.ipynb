# %% [markdown]
# # HPU-Net / sPU-Net — Colab Evaluation (GitHub code + Drive tar.gz data)
#
# This Colab notebook:
# - pulls **code from GitHub**,
# - reads a **`.tar.gz` dataset from Google Drive**,
# - **extracts** the dataset into `/content/` on each run,
# - builds **CSV manifests each run** against the extracted path,
# - and runs the **sPU and HPU evaluation** + basic comparison plots.
#
# Original `spu_hpu_eval_compare.ipynb` cells are preserved at the end (outputs cleared).

# %%
#@title ① Bootstrap: GitHub (code) + Mount Drive (data in tar.gz)
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os, sys

# --- Configure your repo here ---
REPO_URL = "https://github.com/your-user/HPU-Net.git"  #@param {type:"string"}
REPO_BRANCH = "main"  #@param {type:"string"}

PROJECT_DIR = "/content/HPU-Net"

# Clone or update
if os.path.isdir(PROJECT_DIR) and os.path.isdir(os.path.join(PROJECT_DIR, ".git")):
    # %cd "$PROJECT_DIR"
    # !git fetch origin
    # !git checkout "$REPO_BRANCH"
    # !git pull --ff-only origin "$REPO_BRANCH"
else:
    # %cd /content
    # !rm -rf "$PROJECT_DIR"
    # !git clone --depth 1 -b "$REPO_BRANCH" "$REPO_URL" HPU-Net
    # %cd "$PROJECT_DIR"

# Make src importable
if os.path.join(PROJECT_DIR, "src") not in sys.path:
    sys.path.append(os.path.join(PROJECT_DIR, "src"))

# Install dependencies
# !pip -q install --upgrade pip
if os.path.exists("requirements.txt"):
    # !pip -q install -r requirements.txt

print("Repo ready at:", PROJECT_DIR)
# !ls -la

# %%
#@title ② Extract data from Drive tar.gz into /content and set DATA_ROOT
#@markdown Provide the path to your **.tar.gz** dataset file in Drive and where to extract it in `/content`.
#@markdown If the tar contains a top-level directory, we'll auto-detect it. Otherwise, set `SUBDIR`.
TAR_GZ_PATH = "/content/drive/MyDrive/data/lidc_crops.tar.gz"  #@param {type:"string"}
EXTRACT_TO = "/content/lidc_crops"                             #@param {type:"string"}
SUBDIR = ""                                                    #@param {type:"string"}

import os, pathlib, tarfile

# Prepare extract destination
dest = pathlib.Path(EXTRACT_TO)
if dest.exists():
    # Clean previous extraction to ensure a fresh state
    import shutil
    shutil.rmtree(dest)
dest.mkdir(parents=True, exist_ok=True)

# Copy to /content for faster untar
LOCAL_TAR = "/content/dataset.tar.gz"
if os.path.exists(LOCAL_TAR):
    os.remove(LOCAL_TAR)
os.system(f'cp "{TAR_GZ_PATH}" "{LOCAL_TAR}"')

# Extract
with tarfile.open(LOCAL_TAR, "r:gz") as tf:
    tf.extractall(path=EXTRACT_TO)

# Auto-detect top-level directory if SUBDIR not provided
root = pathlib.Path(EXTRACT_TO)
top_items = [p for p in root.iterdir() if p.name not in (".", "..")]
if SUBDIR.strip():
    data_root = root / SUBDIR.strip().strip("/")
elif len(top_items) == 1 and top_items[0].is_dir():
    data_root = top_items[0]
else:
    data_root = root

DATA_ROOT = str(data_root.resolve())
print("DATA_ROOT =", DATA_ROOT)

# Create handy symlink
symlink = "/content/data_lidc_crops"
if os.path.islink(symlink) or os.path.exists(symlink):
    try:
        os.unlink(symlink)
    except Exception:
        pass
os.system(f'ln -s "{DATA_ROOT}" "{symlink}"')
os.system("ls -la /content | grep data_lidc_crops || true")

# %%
#@title ③ Build CSV Manifests (runs every time for extracted data)
#@markdown This will (re)build manifests for the freshly extracted dataset in `/content`.
import os
assert os.path.isdir(DATA_ROOT), f"DATA_ROOT not found: {DATA_ROOT}"
# %cd "$PROJECT_DIR"
# !python -m src.scripts.build_manifests --data-root "$DATA_ROOT"
print("Manifests built for:", DATA_ROOT)

# %%
#@title ④ Configs & Runtime Parameters
SPU_CONFIG = "configs/train_spu_lidc.json"  #@param {type:"string"}
HPU_CONFIG = "configs/train_hpu_lidc.json"  #@param {type:"string"}

SPU_CHECKPOINT = "/content/drive/MyDrive/checkpoints/spu_last.pth"       #@param {type:"string"}
HPU_CHECKPOINT = "/content/drive/MyDrive/checkpoints/hpu_step_50000.pth" #@param {type:"string"}

OUTPUT_DIR = "/content/outputs"  #@param {type:"string"}
NUM_SAMPLES = 10                  #@param {type:"integer"}
NUM_EXAMPLES = 10                 #@param {type:"integer"}

import pathlib
pathlib.Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

print("SPU_CONFIG     =", SPU_CONFIG)
print("HPU_CONFIG     =", HPU_CONFIG)
print("SPU_CHECKPOINT =", SPU_CHECKPOINT)
print("HPU_CHECKPOINT =", HPU_CHECKPOINT)
print("OUTPUT_DIR     =", OUTPUT_DIR)
print("NUM_SAMPLES    =", NUM_SAMPLES)
print("NUM_EXAMPLES   =", NUM_EXAMPLES)
print("DATA_ROOT      =", DATA_ROOT)

# %%
#@title ⑤ Run sPU Evaluation
# %cd "$PROJECT_DIR"
# !python -m src.hpunet.eval.spu_evaluation_script \
  --checkpoint "$SPU_CHECKPOINT" \
  --config "$SPU_CONFIG" \
  --data-root "$DATA_ROOT" \
  --output-dir "$OUTPUT_DIR/spu" \
  --num-samples "$NUM_SAMPLES" \
  --num-examples "$NUM_EXAMPLES"

# %%
#@title ⑥ Run HPU Evaluation
# %cd "$PROJECT_DIR"
# !python -m src.hpunet.eval.hpu_evaluation_script \
  --checkpoint "$HPU_CHECKPOINT" \
  --config "$HPU_CONFIG" \
  --data-root "$DATA_ROOT" \
  --output-dir "$OUTPUT_DIR/hpu"

# %%
#@title ⑦ Compare & Plot Metrics
import os, glob, pandas as pd, matplotlib.pyplot as plt

def newest(csvs):
    return max(csvs, key=os.path.getmtime) if csvs else None

spu_csvs = glob.glob(os.path.join(OUTPUT_DIR, "spu", "**", "*.csv"), recursive=True)
hpu_csvs = glob.glob(os.path.join(OUTPUT_DIR, "hpu", "**", "*.csv"), recursive=True)
spu_csv = newest(spu_csvs)
hpu_csv = newest(hpu_csvs)
print("SPU CSV:", spu_csv)
print("HPU CSV:", hpu_csv)

dfs, labels = [], []
if spu_csv:
    dfs.append(pd.read_csv(spu_csv))
    labels.append("sPU")
if hpu_csv:
    dfs.append(pd.read_csv(hpu_csv))
    labels.append("HPU")

if dfs:
    common = set(dfs[0].columns)
    for d in dfs[1:]:
        common &= set(d.columns)
    preferred = [c for c in ["iou","dice","bce","kl","nll","loss"] if c in common]
    metrics = preferred or list(common)

    means = {lab: dfs[i][metrics].mean() for i, lab in enumerate(labels)}
    summary = pd.DataFrame({lab: means[lab] for lab in labels})
    print("\\n=== Mean Metrics ===")
    print(summary)

    for metric in metrics[:6]:
        plt.figure()
        vals = [means[lab][metric] for lab in labels]
        plt.bar(labels, vals)
        plt.title(f"{metric} (mean)")
        plt.ylabel(metric)
        plt.show()
else:
    print("No CSVs found in OUTPUT_DIR. Run eval cells first.")

# %% [markdown]
# ### Troubleshooting
# - **Tar layout**: If your tar extracts multiple items at top-level, set `SUBDIR` to the folder that contains the actual dataset.
# - **`FileNotFoundError`**: Ensure `TAR_GZ_PATH` is correct and accessible from Drive.
# - **Slow Drive**: Copy checkpoints to `/content/` first for speed, if needed.
# - **`load_state_dict`**: Adjust evaluation scripts to handle checkpoints with/without a `"model"` wrapper, or use `strict=False`.
# - **GPU**: Runtime → Change runtime type → GPU.

# %% [markdown]
# ---

# %% [markdown]
# ## Original notebook cells (preserved below)

# %% [markdown]
# # sPUNet vs HPUNet Comparative Evaluation
#
# This notebook compares the performance of two probabilistic models for lung nodule segmentation on the LIDC dataset. Both models operate on the same data but have different architectures.
#
# **Key Evaluation Strategy:**
# - **Case 1:** All cases (actual lesions + no lesion) - measures overall clinical performance
# - **Case 2:** Only actual lesions - measures pure detection capability when lesions exist
#
# The idea is to see how good each model is at both predicting "nothing there" and finding real lesions.

# %% [markdown]
# ## Configuration
# Update these paths for your system:

# %%
# Model and data paths - UPDATE THESE!!
SPUNET_CHECKPOINT = "/home/cdev/git/HPU-Net/runs/runs/iwi9140h-project/spu/run_20250829_082129_1197064/spu_last.pth"  # Update this path
SPUNET_CONFIG = "/home/cdev/git/HPU-Net/runs/runs/iwi9140h-project/spu/run_20250829_082129_1197064/train_spu_lidc.json"         # Update this path
HPUNET_CHECKPOINT = "/home/cdev/git/HPU-Net/runs/runs/iwi9140h-project/hpu/run_20250829_082159_1197065/hpu_last.pth"  # Update this path  
HPUNET_CONFIG = "/home/cdev/git/HPU-Net/runs/runs/iwi9140h-project/hpu/run_20250829_082159_1197065/train_hpu_lidc.json"         # Update this path

DATA_ROOT = "/home/cdev/git/HPU-Net/data/lidc_crops"                      # Update this path
CSV_NAME = "test.csv"                               

# Evaluation parameters
OUTPUT_DIR = "/home/cdev/git/HPU-Net/runs/runs/iwi9140h-project/comparative_evaluation_results"
NUM_EXAMPLES = 5          # Number of cases to visualize
NUM_SAMPLES = 8          # Prior samples per model per case
DEVICE = "cuda"           
EVAL_SCOPE = "all"        # "all" or "visualize_only"
GED_CLAMP_NONNEG = True   

# viz settings
TITLE_FONTSIZE = 14
FOOTER_FONTSIZE = 12
FIGURE_DPI = 150

print("Config loaded - dont forget to update the paths above!")

# %% [markdown]
# ## Setup Python Path
# This is equivalent to `export PYTHONPATH="$(pwd)/src"` in terminal

# %%
import sys
from pathlib import Path

# add src directory to python path
# equivalent to: export PYTHONPATH="$(pwd)/src" from HPU-Net root
# we need to go up to project root first
current_dir = Path.cwd()
print(f"current directory: {current_dir}")

# find HPU-Net root (go up until we find it)
project_root = current_dir
while project_root.name != "HPU-Net" and project_root.parent != project_root:
    project_root = project_root.parent

if project_root.name != "HPU-Net":
    # fallback: assume we're somewhere under HPU-Net, go up 3 levels
    project_root = current_dir.parent.parent.parent

src_path = project_root / "src"
print(f"project root: {project_root}")
print(f"adding to path: {src_path}")

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))
    print("added src to python path")
else:
    print("src already in python path")

# verify the path is correct by checking if hpunet exists
if (src_path / "hpunet").exists():
    print("hpunet module found at correct path")
else:
    print("ERROR: hpunet module not found - check paths!")
    print(f"looking for: {src_path / 'hpunet'}")

# %% [markdown]
# ## Imports and Setup
# Loading all the stuff we need...

# %%
from __future__ import annotations
from typing import List, Optional, Dict, Tuple
import csv

import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# model imports - should work now with pythonpath set
from hpunet.data.dataset import LIDCCropsDataset
from hpunet.models.spu_net import sPUNet
from hpunet.models.hpu_net import HPUNet
from hpunet.utils.config import load_config


# setup device and dirs
device = torch.device(DEVICE if torch.cuda.is_available() else "cpu")
output_dir = Path(OUTPUT_DIR)
output_dir.mkdir(parents=True, exist_ok=True)

print(f"using device: {device}")
print(f"output directory: {output_dir}")

# %% [markdown]
# ## Utility Functions
# Helper functions for tensor conversion and metric computation

# %%
def tensor_to_numpy_mask(tensor, threshold=0.5):
    """convert logits/prob tensor to binary mask"""
    t = tensor.detach()
    if t.dim() == 4:
        t = t.squeeze(0).squeeze(0)
    elif t.dim() == 3:
        t = t.squeeze(0)
    arr = t.cpu().numpy().astype(np.float32)
    
    # sigmoid if needed
    if arr.max() > 1.0 or arr.min() < 0.0:
        arr = 1.0 / (1.0 + np.exp(-arr))
    
    return (arr > threshold).astype(np.uint8)


def tensor_to_numpy_ct_image(tensor):
    """convert CT tensor to numpy for display"""
    t = tensor.detach()
    if t.dim() == 4:
        t = t.squeeze(0).squeeze(0)
    elif t.dim() == 3:
        t = t.squeeze(0)
    arr = t.cpu().numpy().astype(np.float32)
    
    # rescale to 0-1
    vmin, vmax = float(arr.min()), float(arr.max())
    if vmax > vmin:
        arr = (arr - vmin) / (vmax - vmin)
    else:
        arr = np.zeros_like(arr)
    
    return arr


def is_empty_mask(mask):
    """check if mask is totally black"""
    return mask.sum() == 0


def iou_binary(a, b):
    """basic IoU computation"""
    inter = np.logical_and(a > 0, b > 0).sum(dtype=np.float64)
    union = np.logical_or(a > 0, b > 0).sum(dtype=np.float64)
    
    if union == 0.0:
        return 1.0  # both empty = perfect
    
    return float(inter / union)


def pairwise_iou(set_A, set_B):
    """compute IoU matrix between two sets"""
    mat = np.zeros((len(set_A), len(set_B)), dtype=np.float64)
    for i, a in enumerate(set_A):
        for j, b in enumerate(set_B):
            mat[i, j] = iou_binary(a, b)
    return mat


print("utility functions ready")

# %% [markdown]
# ## Metrics Computation Functions
#
# The main idea here is to compute metrics for both evaluation cases:
# - **Case 1**: Include everything (tests overall performance)
# - **Case 2**: Only non-empty ground truth (tests lesion detection ability)
#
# **Benchmark values from HPU-Net paper (Case 1 only):**
# - **Reconstruction IoU**: HPU-Net 0.97±0.00, sPU-Net 0.75±0.04
# - **GED²**: HPU-Net 0.27±0.01, sPU-Net 0.32±0.03
# - **Hungarian-matched IoU**: HPU-Net 0.53±0.01, sPU-Net 0.50±0.03

# %%
def ged2_iou(set_S, set_Y, clamp_nonneg=True):
    """
    GED² using IoU distance
    GED² = 2*E[d(S,Y)] - E[d(S,S')] - E[d(Y,Y')]
    where d = 1 - IoU
    """
    if len(set_S) == 0 or len(set_Y) == 0:
        return {
            "GED2": float("nan"), 
            "E_IoU_SY": float("nan"), 
            "E_IoU_YY": float("nan"), 
            "E_IoU_SS": float("nan")
        }

    # compute pairwise IoU matrices
    iou_SY = pairwise_iou(set_S, set_Y)
    iou_SS = pairwise_iou(set_S, set_S)
    iou_YY = pairwise_iou(set_Y, set_Y)
    
    # expectations (includes diagonal)
    E_IoU_SY = float(iou_SY.mean())
    E_IoU_SS = float(iou_SS.mean())
    E_IoU_YY = float(iou_YY.mean())
    
    # convert to distance and compute GED²
    E_d_SY = 1.0 - E_IoU_SY
    E_d_SS = 1.0 - E_IoU_SS
    E_d_YY = 1.0 - E_IoU_YY
    
    GED2 = 2.0 * E_d_SY - E_d_SS - E_d_YY
    
    # clamp to avoid tiny negatives from sampling bias
    if clamp_nonneg and np.isfinite(GED2) and GED2 < 0.0:
        GED2 = 0.0

    return {
        "GED2": float(GED2), 
        "E_IoU_SY": E_IoU_SY, 
        "E_IoU_YY": E_IoU_YY, 
        "E_IoU_SS": E_IoU_SS
    }


def reconstruction_iou(reconstructions, ground_truths):
    """
    Reconstruction IoU (IoUrec): measures how well model can reconstruct given GT
    Average IoU between each reconstruction and its corresponding ground truth
    """
    if len(reconstructions) == 0 or len(ground_truths) == 0:
        return float("nan")
    
    ious = []
    for i, (recon, gt) in enumerate(zip(reconstructions, ground_truths)):
        iou = iou_binary(recon, gt)
        ious.append(iou)
    
    return float(np.mean(ious))


def hungarian_matched_iou(set_S, set_Y):
    """
    Hungarian-matched IoU: optimal 1:1 matching between samples and GT
    Uses Hungarian algorithm to find best pairing, then averages IoU
    """
    if len(set_S) == 0 or len(set_Y) == 0:
        return float("nan")
    
    # duplicate sets to same size (LCM) as described in paper
    from math import gcd
    lcm = len(set_S) * len(set_Y) // gcd(len(set_S), len(set_Y))
    
    # replicate each set to LCM size
    extended_S = []
    extended_Y = []
    
    for i in range(lcm):
        extended_S.append(set_S[i % len(set_S)])
        extended_Y.append(set_Y[i % len(set_Y)])
    
    # compute cost matrix (1 - IoU for minimization)
    cost_matrix = np.zeros((len(extended_S), len(extended_Y)))
    for i, s in enumerate(extended_S):
        for j, y in enumerate(extended_Y):
            cost_matrix[i, j] = 1.0 - iou_binary(s, y)
    
    # apply Hungarian algorithm
    try:
        from scipy.optimize import linear_sum_assignment
        row_indices, col_indices = linear_sum_assignment(cost_matrix)
        
        # compute average IoU of matched pairs
        matched_ious = []
        for r, c in zip(row_indices, col_indices):
            iou = 1.0 - cost_matrix[r, c]  # convert back from cost
            matched_ious.append(iou)
        
        return float(np.mean(matched_ious))
        
    except ImportError:
        # fallback: simple average without optimal matching
        print("warning: scipy not available for Hungarian algorithm, using simple average")
        iou_matrix = pairwise_iou(set_S, set_Y)
        return float(iou_matrix.mean())


print("all metric functions ready (including new IoUrec and Hungarian-matched IoU)")

# %% [markdown]
# ## Model Loading Functions
# Loading both model architectures with their specific parameters

# %%
def load_spunet(ckpt_path, device):
    """load sPUNet from checkpoint"""
    ckpt = torch.load(ckpt_path, map_location=device)
    # sPUNet uses these params based on the original script
    model = sPUNet(in_ch=1, base=32, z_dim=6).to(device)
    model.load_state_dict(ckpt["model"])
    model.eval()
    print(f"loaded sPUNet from step {ckpt.get('step', 'unknown')}")
    return model


def load_hpunet(ckpt_path, device):
    """load HPUNet from checkpoint"""
    ckpt = torch.load(ckpt_path, map_location=device)
    # HPUNet uses different params
    model = HPUNet(in_ch=1, base=24, z_ch=1, n_blocks=3).to(device)
    model.load_state_dict(ckpt["model"])
    model.eval()
    print(f"loaded HPUNet from step {ckpt.get('step', 'unknown')}")
    return model

print("model loading functions ready")

# %% [markdown]
# ## Load Both Models
# Actually loading the models here - make sure your paths are correct above!

# %%
print("loading models...")

spu_model = load_spunet(Path(SPUNET_CHECKPOINT), device)
hpu_model = load_hpunet(Path(HPUNET_CHECKPOINT), device)

# load configs too (might need them later)
spu_config = load_config(Path(SPUNET_CONFIG))
hpu_config = load_config(Path(HPUNET_CONFIG))

print("both models loaded successfully!")

# %% [markdown]
# ## Dataset Setup
# Using the same dataset for both models to ensure fair comparison

# %%
# setup dataset
csv_path = Path(DATA_ROOT) / CSV_NAME
dataset = LIDCCropsDataset(
    csv_path=csv_path,
    project_root=Path(DATA_ROOT).parent.parent,
    image_size=128,
    augment=False,  # no augmentation for eval
    seed=42,        # fixed seed for reproducibility
)

dataloader = DataLoader(
    dataset, 
    batch_size=1, 
    shuffle=False,  # keep order for comparison
    num_workers=2
)

print(f"loaded dataset with {len(dataset)} samples from {csv_path.name}")
print(f"will process {'all samples' if EVAL_SCOPE == 'all' else f'first {NUM_EXAMPLES} for visualization'}")

# %% [markdown]
# ## Inference Functions
# These work with both model types since they have the same interface

# %%
@torch.no_grad()
def generate_reconstructions(model, image, grader_masks):
    """generate posterior reconstructions for any model"""
    reconstructions = []
    for grader_idx in range(grader_masks.shape[1]):  # usually 4 graders
        grader_mask = grader_masks[:, grader_idx : grader_idx + 1, :, :].float()
        logits, _ = model(x=image, y_target=grader_mask, sample_posterior=True)
        reconstructions.append(logits)
    return reconstructions


@torch.no_grad()
def generate_samples(model, image, num_samples=24):
    """generate prior samples"""
    samples = []
    for _ in range(num_samples):
        logits, _ = model(x=image, y_target=None, sample_posterior=False)
        samples.append(logits)
    return samples


print("inference functions ready")

# %%
def compute_comparative_metrics_all_cases(spu_reconstructions, hpu_reconstructions, grader_masks, spu_samples, hpu_samples, clamp_nonneg=True):
    """
    Case 1: ALL cases included (actual lesions + no lesion)
    measures overall performance including "nothing there" prediction
    """
    
    if len(grader_masks) == 0:
        return {
            "num_graders": 0,
            "spu_GED2_all": float("nan"), "spu_E_IoU_SY_all": float("nan"),
            "hpu_GED2_all": float("nan"), "hpu_E_IoU_SY_all": float("nan"),
            "spu_E_IoU_SS_all": float("nan"), "spu_E_IoU_YY_all": float("nan"),
            "hpu_E_IoU_SS_all": float("nan"), "hpu_E_IoU_YY_all": float("nan"),
            "spu_IoUrec_all": float("nan"), "hpu_IoUrec_all": float("nan"),
            "spu_Hungarian_all": float("nan"), "hpu_Hungarian_all": float("nan")
        }
    
    # GED² for both models
    spu_ged_metrics = ged2_iou(spu_reconstructions, grader_masks, clamp_nonneg)
    hpu_ged_metrics = ged2_iou(hpu_reconstructions, grader_masks, clamp_nonneg)
    
    # Reconstruction IoU (IoUrec)
    spu_iourec = reconstruction_iou(spu_reconstructions, grader_masks)
    hpu_iourec = reconstruction_iou(hpu_reconstructions, grader_masks)
    
    # Hungarian-matched IoU (using samples vs GT)
    spu_hungarian = hungarian_matched_iou(spu_samples, grader_masks)
    hpu_hungarian = hungarian_matched_iou(hpu_samples, grader_masks)
    
    return {
        "num_graders": len(grader_masks),
        "spu_GED2_all": spu_ged_metrics["GED2"],
        "spu_E_IoU_SY_all": spu_ged_metrics["E_IoU_SY"], 
        "spu_E_IoU_SS_all": spu_ged_metrics["E_IoU_SS"],
        "spu_E_IoU_YY_all": spu_ged_metrics["E_IoU_YY"],
        "hpu_GED2_all": hpu_ged_metrics["GED2"],
        "hpu_E_IoU_SY_all": hpu_ged_metrics["E_IoU_SY"],
        "hpu_E_IoU_SS_all": hpu_ged_metrics["E_IoU_SS"], 
        "hpu_E_IoU_YY_all": hpu_ged_metrics["E_IoU_YY"],
        "spu_IoUrec_all": spu_iourec,
        "hpu_IoUrec_all": hpu_iourec,
        "spu_Hungarian_all": spu_hungarian,
        "hpu_Hungarian_all": hpu_hungarian
    }


def compute_comparative_metrics_nonempty_only(spu_reconstructions, hpu_reconstructions, grader_masks, spu_samples, hpu_samples, clamp_nonneg=True):
    """
    Case 2: only non-empty GT (actual lesions only)
    measures detection performance when lesions are present
    """
    
    # filter out empty GT masks
    non_empty_indices = [i for i, mask in enumerate(grader_masks) if not is_empty_mask(mask)]
    
    if len(non_empty_indices) == 0:
        return {
            "num_nonempty_graders": 0,
            "spu_GED2_nonempty": float("nan"), "spu_E_IoU_SY_nonempty": float("nan"),
            "hpu_GED2_nonempty": float("nan"), "hpu_E_IoU_SY_nonempty": float("nan"),
            "spu_E_IoU_SS_nonempty": float("nan"), "spu_E_IoU_YY_nonempty": float("nan"),
            "hpu_E_IoU_SS_nonempty": float("nan"), "hpu_E_IoU_YY_nonempty": float("nan"),
            "spu_IoUrec_nonempty": float("nan"), "hpu_IoUrec_nonempty": float("nan"),
            "spu_Hungarian_nonempty": float("nan"), "hpu_Hungarian_nonempty": float("nan")
        }
    
    # get only non-empty graders and corresponding reconstructions
    non_empty_graders = [grader_masks[i] for i in non_empty_indices]
    spu_recons_nonempty = [spu_reconstructions[i] for i in non_empty_indices]
    hpu_recons_nonempty = [hpu_reconstructions[i] for i in non_empty_indices]
    
    # compute all metrics on filtered data
    spu_ged_metrics = ged2_iou(spu_recons_nonempty, non_empty_graders, clamp_nonneg)
    hpu_ged_metrics = ged2_iou(hpu_recons_nonempty, non_empty_graders, clamp_nonneg)
    
    spu_iourec = reconstruction_iou(spu_recons_nonempty, non_empty_graders)
    hpu_iourec = reconstruction_iou(hpu_recons_nonempty, non_empty_graders)
    
    spu_hungarian = hungarian_matched_iou(spu_samples, non_empty_graders)
    hpu_hungarian = hungarian_matched_iou(hpu_samples, non_empty_graders)
    
    return {
        "num_nonempty_graders": len(non_empty_graders),
        "spu_GED2_nonempty": spu_ged_metrics["GED2"],
        "spu_E_IoU_SY_nonempty": spu_ged_metrics["E_IoU_SY"], 
        "spu_E_IoU_SS_nonempty": spu_ged_metrics["E_IoU_SS"],
        "spu_E_IoU_YY_nonempty": spu_ged_metrics["E_IoU_YY"],
        "hpu_GED2_nonempty": hpu_ged_metrics["GED2"],
        "hpu_E_IoU_SY_nonempty": hpu_ged_metrics["E_IoU_SY"],
        "hpu_E_IoU_SS_nonempty": hpu_ged_metrics["E_IoU_SS"], 
        "hpu_E_IoU_YY_nonempty": hpu_ged_metrics["E_IoU_YY"],
        "spu_IoUrec_nonempty": spu_iourec,
        "hpu_IoUrec_nonempty": hpu_iourec,
        "spu_Hungarian_nonempty": spu_hungarian,
        "hpu_Hungarian_nonempty": hpu_hungarian
    }


def compute_individual_ious(reconstructions, grader_masks):
    """
    compute IoU for each recon vs corresponding grader
    used for visualization - always computed
    """
    ious = []
    for i in range(len(reconstructions)):
        if i < len(grader_masks):
            grader = grader_masks[i]
            recon = reconstructions[i]
            ious.append(iou_binary(recon, grader))
        else:
            ious.append(None)
    
    return ious


print("metrics functions ready")

# %% [markdown]
# ## Visualization Function
#
# Creates side-by-side comparison showing both models on the same data.
# The layout shows graders, then sPUNet results, then HPUNet results, then samples from both.

# %%
def create_comparative_visualization(ct_scan, grader_masks, spu_reconstructions, hpu_reconstructions, spu_ious, hpu_ious, spu_samples, hpu_samples, save_path):
    """
    side-by-side comparison viz:
    Row 1: [CT] [grader1] [grader2] [grader3] [grader4] [empty]
    Row 2: [empty] [sPU_recon1] [sPU_recon2] [sPU_recon3] [sPU_recon4] [empty]  
    Row 3: [empty] [HPU_recon1] [HPU_recon2] [HPU_recon3] [HPU_recon4] [empty]
    Row 4: [sPU_sample1-6]
    Row 5: [HPU_sample1-6]
    """
    fig = plt.figure(figsize=(18, 15))
    
    def add_subplot(row, col, img, title, show_iou=False, iou_val=None):
        ax = fig.add_subplot(5, 6, row * 6 + col + 1)
        ax.imshow(img, cmap="gray", vmin=0, vmax=1)
        ax.set_title(title, fontsize=TITLE_FONTSIZE, loc="right")
        ax.axis("off")
        
        if show_iou:
            if iou_val is None:
                txt = "IoU=NA"
            elif np.isnan(iou_val):
                txt = "IoU=NA"
            else:
                txt = f"IoU={iou_val:.3f}"
            ax.text(1.0, -0.08, txt, transform=ax.transAxes, 
                   ha="right", va="top", fontsize=FOOTER_FONTSIZE)
        
        return ax
    
    # row 1: CT + graders
    add_subplot(0, 0, ct_scan, "CT")
    for i in range(min(4, len(grader_masks))):
        add_subplot(0, i + 1, grader_masks[i], f"grader {i+1}")
    
    # row 2: sPUNet reconstructions
    for i in range(min(4, len(spu_reconstructions))):
        title = f"sPU_recon {i+1}" if i > 0 else "sPUNet Reconstructions\nsPU_recon 1"
        add_subplot(1, i + 1, spu_reconstructions[i], title, show_iou=True, iou_val=spu_ious[i])
    
    # row 3: HPUNet reconstructions  
    for i in range(min(4, len(hpu_reconstructions))):
        title = f"HPU_recon {i+1}" if i > 0 else "HPUNet Reconstructions\nHPU_recon 1"
        add_subplot(2, i + 1, hpu_reconstructions[i], title, show_iou=True, iou_val=hpu_ious[i])
    
    # row 4: sPUNet samples
    for i in range(min(6, len(spu_samples))):
        title = f"sPU_s{i+1}" if i > 0 else "sPUNet Samples\nsPU_s1"
        add_subplot(3, i, spu_samples[i], title)
    
    # row 5: HPUNet samples
    for i in range(min(6, len(hpu_samples))):
        title = f"HPU_s{i+1}" if i > 0 else "HPUNet Samples\nHPU_s1"
        add_subplot(4, i, hpu_samples[i], title)
    
    plt.tight_layout()
    plt.savefig(save_path, dpi=FIGURE_DPI, bbox_inches="tight")
    plt.close()
    print(f"saved: {save_path}")


print("visualization function ready")

# %% [markdown]
# ## Main Evaluation Loop
#
# This is where the magic happens - we run both models on the same data and collect all the metrics.
#
# For each sample, we:
# 1. Generate reconstructions from both models
# 2. Generate prior samples from both models
# 3. Compute metrics for both evaluation cases
# 4. Create comparative visualizations
# 5. Store everything for analysis

# %%
print("starting comparative evaluation...")

# storage for results
all_case_metrics = []      # all cases in CSV scope

num_visualized = 0

for row_idx, batch in enumerate(dataloader):
    if EVAL_SCOPE == "visualize_only" and num_visualized >= NUM_EXAMPLES:
        break
    
    if row_idx % 10 == 0:  # progress update
        print(f"processing row {row_idx}...")
    
    # get inputs
    image = batch["image"].to(device)  # [1,1,H,W]
    masks = batch["masks"].to(device)  # [1,4,H,W]
    
    # generate predictions for both models on same input
    spu_reconstructions = generate_reconstructions(spu_model, image, masks)
    hpu_reconstructions = generate_reconstructions(hpu_model, image, masks)
    
    spu_samples = generate_samples(spu_model, image, NUM_SAMPLES)
    hpu_samples = generate_samples(hpu_model, image, NUM_SAMPLES)
    
    # convert everything to numpy
    ct_scan = tensor_to_numpy_ct_image(image)
    grader_masks_np = [tensor_to_numpy_mask(masks[:, i:i+1]) for i in range(masks.shape[1])]
    
    spu_reconstructions_np = [tensor_to_numpy_mask(r) for r in spu_reconstructions]
    hpu_reconstructions_np = [tensor_to_numpy_mask(r) for r in hpu_reconstructions]
    
    spu_samples_np = [tensor_to_numpy_mask(s) for s in spu_samples]
    hpu_samples_np = [tensor_to_numpy_mask(s) for s in hpu_samples]
    
    # check what graders we have
    grader_available = [not is_empty_mask(mask) for mask in grader_masks_np]
    num_available_graders = sum(grader_available)
    total_graders = len(grader_masks_np)
    
    # compute metrics for CASE 1: all cases (overall performance)
    metrics_all_included = compute_comparative_metrics_all_cases(
        spu_reconstructions_np, hpu_reconstructions_np, grader_masks_np, 
        spu_samples_np, hpu_samples_np, GED_CLAMP_NONNEG
    )
    
    # compute metrics for CASE 2: non-empty GT only (lesion detection)
    metrics_nonempty_only = compute_comparative_metrics_nonempty_only(
        spu_reconstructions_np, hpu_reconstructions_np, grader_masks_np,
        spu_samples_np, hpu_samples_np, GED_CLAMP_NONNEG
    )
    
    # individual IoUs for viz
    spu_ious = compute_individual_ious(spu_reconstructions_np, grader_masks_np)
    hpu_ious = compute_individual_ious(hpu_reconstructions_np, grader_masks_np)
    
    # store comprehensive metrics
    all_case_row = {
        "row_idx": row_idx,
        "total_graders": total_graders,
        "num_available_graders": num_available_graders,
        # case 1 metrics
        **{k: v for k, v in metrics_all_included.items()},
        # case 2 metrics  
        **{k: v for k, v in metrics_nonempty_only.items()}
    }
    all_case_metrics.append(all_case_row)
    
    # create visualization for first N examples
    if num_visualized < NUM_EXAMPLES:
        save_path = output_dir / f"comparative_row_{row_idx:05d}.png"
        create_comparative_visualization(
            ct_scan, grader_masks_np, 
            spu_reconstructions_np, hpu_reconstructions_np,
            spu_ious, hpu_ious,
            spu_samples_np[:6], hpu_samples_np[:6],
            save_path
        )
        num_visualized += 1
    
    if EVAL_SCOPE == "visualize_only" and num_visualized >= NUM_EXAMPLES:
        break

print(f"evaluation complete - processed {len(all_case_metrics)} cases")

# %% [markdown]
# ## Results Export
# Saving detailed metrics to CSV files for further analysis

# %%
def save_metrics_csv(metrics_list, filename):
    """save metrics to CSV"""
    if not metrics_list:
        print(f"no data to save for {filename}")
        return
        
    csv_path = output_dir / filename
    fieldnames = list(metrics_list[0].keys())
    
    with open(csv_path, 'w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(metrics_list)
    
    print(f"saved: {csv_path}")


# save the detailed results
save_metrics_csv(all_case_metrics, "comparative_metrics_all_cases.csv")

# %% [markdown]
# ## Results Export
# Saving detailed metrics to CSV files for further analysis

# %%
def print_summary_statistics(metrics_list, label):
    """print summary stats with benchmark comparison"""
    if not metrics_list:
        print(f"[{label}] no data")
        return
    
    print(f"\n{label} - Total: {len(metrics_list)}")
    
    # case 1: all cases with benchmarks
    spu_ged2_all = np.array([r["spu_GED2_all"] for r in metrics_list if not np.isnan(r["spu_GED2_all"])])
    hpu_ged2_all = np.array([r["hpu_GED2_all"] for r in metrics_list if not np.isnan(r["hpu_GED2_all"])])
    spu_iourec_all = np.array([r["spu_IoUrec_all"] for r in metrics_list if not np.isnan(r["spu_IoUrec_all"])])
    hpu_iourec_all = np.array([r["hpu_IoUrec_all"] for r in metrics_list if not np.isnan(r["hpu_IoUrec_all"])])
    spu_hungarian_all = np.array([r["spu_Hungarian_all"] for r in metrics_list if not np.isnan(r["spu_Hungarian_all"])])
    hpu_hungarian_all = np.array([r["hpu_Hungarian_all"] for r in metrics_list if not np.isnan(r["hpu_Hungarian_all"])])
    
    if len(spu_ged2_all) > 0 and len(hpu_ged2_all) > 0:
        print(f"\nCase 1 (All): Valid cases sPU={len(spu_ged2_all)}, HPU={len(hpu_ged2_all)}")
        print(f"GED²      | sPU: {np.mean(spu_ged2_all):.3f}±{np.std(spu_ged2_all):.3f} (paper: 0.32±0.03) | HPU: {np.mean(hpu_ged2_all):.3f}±{np.std(hpu_ged2_all):.3f} (paper: 0.27±0.01)")
        print(f"IoUrec    | sPU: {np.mean(spu_iourec_all):.3f}±{np.std(spu_iourec_all):.3f} (paper: 0.75±0.04) | HPU: {np.mean(hpu_iourec_all):.3f}±{np.std(hpu_iourec_all):.3f} (paper: 0.97±0.00)")
        print(f"Hungarian | sPU: {np.mean(spu_hungarian_all):.3f}±{np.std(spu_hungarian_all):.3f} (paper: 0.50±0.03) | HPU: {np.mean(hpu_hungarian_all):.3f}±{np.std(hpu_hungarian_all):.3f} (paper: 0.53±0.01)")
    
    # case 2: non-empty only (no benchmarks available for this case)
    spu_ged2_nonempty = np.array([r["spu_GED2_nonempty"] for r in metrics_list if not np.isnan(r["spu_GED2_nonempty"])])
    hpu_ged2_nonempty = np.array([r["hpu_GED2_nonempty"] for r in metrics_list if not np.isnan(r["hpu_GED2_nonempty"])])
    spu_iourec_nonempty = np.array([r["spu_IoUrec_nonempty"] for r in metrics_list if not np.isnan(r["spu_IoUrec_nonempty"])])
    hpu_iourec_nonempty = np.array([r["hpu_IoUrec_nonempty"] for r in metrics_list if not np.isnan(r["hpu_IoUrec_nonempty"])])
    spu_hungarian_nonempty = np.array([r["spu_Hungarian_nonempty"] for r in metrics_list if not np.isnan(r["spu_Hungarian_nonempty"])])
    hpu_hungarian_nonempty = np.array([r["hpu_Hungarian_nonempty"] for r in metrics_list if not np.isnan(r["hpu_Hungarian_nonempty"])])
    
    if len(spu_ged2_nonempty) > 0 and len(hpu_ged2_nonempty) > 0:
        print(f"\nCase 2 (Non-empty): Valid cases sPU={len(spu_ged2_nonempty)}, HPU={len(hpu_ged2_nonempty)}")
        print(f"GED²      | sPU: {np.mean(spu_ged2_nonempty):.3f}±{np.std(spu_ged2_nonempty):.3f} | HPU: {np.mean(hpu_ged2_nonempty):.3f}±{np.std(hpu_ged2_nonempty):.3f}")
        print(f"IoUrec    | sPU: {np.mean(spu_iourec_nonempty):.3f}±{np.std(spu_iourec_nonempty):.3f} | HPU: {np.mean(hpu_iourec_nonempty):.3f}±{np.std(hpu_iourec_nonempty):.3f}")
        print(f"Hungarian | sPU: {np.mean(spu_hungarian_nonempty):.3f}±{np.std(spu_hungarian_nonempty):.3f} | HPU: {np.mean(hpu_hungarian_nonempty):.3f}±{np.std(hpu_hungarian_nonempty):.3f}")

# print summary stats
print_summary_statistics(all_case_metrics, "ALL CASES")

# %% [markdown]
# ## Export Summary Table

# %%
# create summary table
summary_data = []
for label, metrics_list in [("All Cases", all_case_metrics)]:
    if not metrics_list:
        continue
    
    # case 1 metrics
    spu_ged2_all = [r["spu_GED2_all"] for r in metrics_list if not np.isnan(r["spu_GED2_all"])]
    hpu_ged2_all = [r["hpu_GED2_all"] for r in metrics_list if not np.isnan(r["hpu_GED2_all"])]
    spu_iourec_all = [r["spu_IoUrec_all"] for r in metrics_list if not np.isnan(r["spu_IoUrec_all"])]
    hpu_iourec_all = [r["hpu_IoUrec_all"] for r in metrics_list if not np.isnan(r["hpu_IoUrec_all"])]
    
    if spu_ged2_all and hpu_ged2_all:
        summary_data.append({
            "Dataset": label,
            "sPUNet_GED2": f"{np.mean(spu_ged2_all):.3f}±{np.std(spu_ged2_all):.3f}",
            "HPUNet_GED2": f"{np.mean(hpu_ged2_all):.3f}±{np.std(hpu_ged2_all):.3f}",
            "sPUNet_IoUrec": f"{np.mean(spu_iourec_all):.3f}±{np.std(spu_iourec_all):.3f}",
            "HPUNet_IoUrec": f"{np.mean(hpu_iourec_all):.3f}±{np.std(hpu_iourec_all):.3f}"
        })

if summary_data:
    save_metrics_csv(summary_data, "summary_comparison.csv")
    print(f"saved summary: {output_dir}/summary_comparison.csv")

# %% [markdown]
# ## Display First Sample Visualization

# %%
# show first comparative visualization inline
first_viz_path = output_dir / "comparative_row_00000.png"
if first_viz_path.exists():
    from IPython.display import Image as IPImage, display
    print(f"first sample: {first_viz_path.name}")
    display(IPImage(str(first_viz_path)))
else:
    print("no visualization found")
